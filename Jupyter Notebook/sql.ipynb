# %%
import mysql.connector as db
import pandas as pd

from IPython.display import display

# %%
connection = db.connect(
                        host="localhost",
                        database="junior_data_analyst",
                        user="root",
                        password="MySQL"
                       )

query = "select * from `sample data`"

data = pd.read_sql(query, connection)

if connection.is_connected():
    connection.close()
    print("MySQL Close")

display(data)
# Out:
# MySQL Close
#           id kemendagri_kabupaten_nama  kemendagri_kabupaten_kode        date  \
# 0    8230974              KOTA BANDUNG                      32.73  2020-01-01
# 1    8230965              KOTA BANDUNG                      32.73  2020-01-01
# 2    8230966              KOTA BANDUNG                      32.73  2020-01-01
# 3    8230967              KOTA BANDUNG                      32.73  2020-01-01
# 4    8230968              KOTA BANDUNG                      32.73  2020-01-01
# ..       ...                       ...                        ...         ...
# 145  8231145              KOTA BANDUNG                      32.73  2020-01-01
# 146  8231114              KOTA BANDUNG                      32.73  2020-01-01
# 147  8231115              KOTA BANDUNG                      32.73  2020-01-01
# 148  8231116              KOTA BANDUNG                      32.73  2020-01-01
# 149  8231117              KOTA BANDUNG                      32.73  2020-01-01
#
# ...

# %%
connection = db.connect(
                        host="localhost",
                        database="junior_data_analyst",
                        user="root",
                        password="MySQL"
                       )

query = "select id, geometry lokasi, count(level) count_level_5 from `sample data` where level = 5 group by id"

data = pd.read_sql(query, connection)

if connection.is_connected():
    connection.close()
    print("MySQL Close")

display(data)
# Out:
# MySQL Close
#          id                                             lokasi  count_level_5
# 0   8230983  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 1   8230994  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 2   8230995  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 3   8230996  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 4   8231018  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 5   8231019  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 6   8231029  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 7   8231041  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 8   8231042  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 9   8231085  {'type': 'MultiLineString', 'coordinates': [[[...              1
# 10  8231087  {'type': 'MultiLineString', 'coordinates': [[[...              1

# %%
connection = db.connect(
                        host="localhost",
                        database="junior_data_analyst",
                        user="root",
                        password="MySQL"
                       )

query = "select id, level level_5 from `sample data` where level = 5 order by id  limit 5"

data = pd.read_sql(query, connection)

if connection.is_connected():
    connection.close()
    print("MySQL Close")

display(data)
# Out:
# MySQL Close
#         id  level_5
# 0  8230983        5
# 1  8230994        5
# 2  8230995        5
# 3  8230996        5
# 4  8231018        5
